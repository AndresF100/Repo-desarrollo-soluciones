# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('./data_for_visuals.csv.xls')

display(df.head())
# Out:
#   dto_igdacmlmasolicitudes pcl_igdacmlmasolicitudes  \
# 0                        s                        s
# 1                        s                        s
# 2                        s                        s
# 3                        s                        s
# 4                        s                        s
#
#    tipo_siniestro_igdacmlmasolicitudes fecha_siniestro_igdacmlmasolicitudes  \
# 0                                    0            2009-03-05 00:00:00+00:00
# 1                                    0            2009-03-04 00:00:00+00:00
# 2                                    0            2009-03-05 00:00:00+00:00
# 3                                    0            2009-03-04 00:00:00+00:00
# 4                                    0            2009-03-05 00:00:00+00:00
#
#    hora_at_igatepmafurat  ind_tipo_jornada_at_igatepmafurat  \
# 0                      9                                  1
# 1                      1                                  1
# ...

# %%
display(df.describe())
display(df.columns)
# Out:
#        tipo_siniestro_igdacmlmasolicitudes  hora_at_igatepmafurat  \
# count                         54638.000000           54638.000000
# mean                              0.381621              11.015831
# std                               0.517282               4.354724
# min                               0.000000               0.000000
# 25%                               0.000000               8.000000
# 50%                               0.000000              11.000000
# 75%                               1.000000              14.000000
# max                               2.000000              24.000000
#
#        ind_tipo_jornada_at_igatepmafurat  horas_previo_at_igatepmafurat  \
# count                       54638.000000                   54638.000000
# mean                            0.891193                       3.559830
# std                             0.363672                       3.250137
# min                             0.000000                       0.000000
# ...

# %%
pip install nltk
# Out:
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 26.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dash
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
