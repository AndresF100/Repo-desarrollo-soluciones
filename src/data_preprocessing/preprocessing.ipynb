# %%
import logging
from data_loader import load_data
from data_cleaning import clean_data

logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

# def run_data_preprocessing_pipeline()

logging.info("Iniciando pipeline de preprocesamiento...")

data = load_data("clasificacion_siniestros.csv")
logging.info(f"✅ Datos cargados: {data.shape[0]} filas y {data.shape[1]} columnas.")


df = clean_data(data.copy())
logging.info(f"✅ Proceso de limpieza finalizado.")
# Out:
# 2025-02-28 16:28:39,788 - INFO - Iniciando pipeline de preprocesamiento...
# 2025-02-28 16:28:39,792 - INFO - Cargando datos desde: D:\OneDrive - Universidad de La Salle\Maestría IA\S4\Desarrollo de soluciones\Proyecto\Repo desarrollo soluciones\data\raw\clasificacion_siniestros.csv
# 2025-02-28 16:28:41,159 - INFO - ✅ Datos cargados: 63164 filas y 66 columnas.
# 2025-02-28 16:28:41,188 - INFO - Iniciando limpieza: (63164, 66) registros.
# 2025-02-28 16:28:41,612 - INFO - Columnas eliminadas por irrelevancia: ['id_furat_furep_igdacmlmasolicitudes', 'id_solicitud_igdacmlmasolicitudes', 'fecha_solicitud_igdacmlmasolicitudes', 'fecha_modificacion_aud_igdacmlmasolicitudes', 'dto_igdacmlmasolicitudes', 'pcl_igdacmlmasolicitudes', 'id_furat_igatepmafurat', 'id_siniestro_igatepmafurat', 'minuto_at_igatepmafurat', 'nombre_ocupacion_igatepmafurat', 'horas_previo_at_igatepmafurat', 'minutos_previo_at_igatepmafurat', 'ind_tipo_at_igatepmafurat', 'ind_muerte_igatepmafurat', 'fecha_muerte_igatepmafurat', 'otro_sitio_ocurrencia_igatepmafurat', 'otro_tipo_lesion_igatepmafurat', 'otro_mecanismo_accidente_igatepmafurat', 'ind_testigo_at_igatepmafurat', 'fecha_diligenciamiento_igatepmafurat', 'fecha_radicacion_igatepmafurat', 'id_medio_recepcion_igatepmafurat', 'oficio_solicitud_igatepmafurat', 'centro_trabajo_igual_igatepmafurat', 'accidente_grave_igatepmafurat', 'riesgo_biologico_igatepmafurat', 'id_sitio_ocurrencia_igatepmafurat', 'monto_reserva_igatepmafurat', 'dias_incapacidad_igatepmafurat', 'muerte_posterior_igatepmafurat', 'estado_reserva_igatepmafurat', 'fecha_aviso_muerte_igatepmafurat', 'fecha_modificacion_aud_igatepmafurat', 'id_solicitud_igacctmimvdiagnosticos', 'cons_diag_igacctmimvdiagnosticos', 'nombre_diagnostico_igacctmimvdiagnosticos', 'tipo_calificador_igacctmimvdiagnosticos', 'tipo_calificacion_igacctmimvdiagnosticos', 'id_calificacion_dto_igdactmlmacalificacionorigen', 'id_solicitud_igdactmlmacalificacionorigen', 'fecha_dictamen_igdactmlmacalificacionorigen', 'fecha_estructuracion_igdactmlmacalificacionorigen', 'fecha_modificacion_aud_igdactmlmacalificacionorigen']
# 2025-02-28 16:28:41,647 - INFO - Columnas eliminadas por alto porcentaje de nulos (>50%): ['id_act_economica_igdacmlmasolicitudes', 'id_dx_igacctmimvdiagnosticos', 'fecha_modificacion_aud_igacctmimvdiagnosticos']
# 2025-02-28 16:28:41,776 - INFO - Total registros eliminados por outliers: 2713.
# 2025-02-28 16:28:41,951 - INFO - Limpieza completada: (60451, 19) registros (cambio de (63164, 66) a (60451, 19)).
# 2025-02-28 16:28:41,951 - INFO - ✅ Proceso de limpieza finalizado.

# %%
# data transformation
# Out:
#        emp_id_igdacmlmasolicitudes  seg_idponderado_igdacmlmasolicitudes  \
# 0                        105339902                                    -1
# 1                        105667103                                    11
# 2                        105320992                                     6
# 3                        105734010                                     6
# 4                        104927847                                    -1
# ...                            ...                                   ...
# 63159                    105256353                                    11
# 63160                    104610013                                    11
# 63161                    105376102                                    -1
# 63162                    105228957                                    11
# 63163                    105188894                                    -1
#
#        tipo_siniestro_igdacmlmasolicitudes  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ...                                    ...
# 63159                                    1
# 63160                                    1
# 63161                                    0
# 63162                                    0
# 63163                                    1
#
#       id_tipo_doc_emp_igdacmlmasolicitudes  \
# 0                                       ni
# 1                                       cc
# 2                                       ni
# 3                                       ni
# 4                                       cc
# ...                                    ...
# 63159                                   ni
# 63160                                   cc
# 63161                                   ni
# 63162                                   ni
# 63163                                   ni
#
#       fecha_siniestro_igdacmlmasolicitudes  hora_at_igatepmafurat  \
# 0                2009-03-05 00:00:00+00:00                      9
# 1                2009-03-04 00:00:00+00:00                      1
# 2                2009-03-05 00:00:00+00:00                     13
# 3                2009-03-04 00:00:00+00:00                     11
# 4                2009-03-05 00:00:00+00:00                     13
# ...                                    ...                    ...
# 63159            2009-08-19 00:00:00+00:00                      7
# 63160            2009-08-20 00:00:00+00:00                     12
# 63161            2009-03-12 00:00:00+00:00                     14
# 63162            2009-03-10 00:00:00+00:00                     10
# 63163            2009-03-12 00:00:00+00:00                     22
#
#        ind_tipo_jornada_at_igatepmafurat  \
# 0                                      1
# 1                                      1
# 2                                      1
# 3                                      1
# 4                                      1
# ...                                  ...
# 63159                                  1
# 63160                                  1
# 63161                                  1
# 63162                                  1
# 63163                                  1
#
#       ind_realizando_trabajo_hab_at_igatepmafurat  \
# 0                                               s
# 1                                               s
# 2                                               s
# 3                                               s
# 4                                               s
# ...                                           ...
# 63159                                           s
# 63160                                           s
# 63161                                           s
# 63162                                           s
# 63163                                           s
#
#        id_ocupacion_at_igatepmafurat  ind_tipo_at_igatepmafurat  ...  \
# 0                             8271.0                          5  ...
# 1                             9223.0                          5  ...
# 2                             2143.0                          5  ...
# 3                             7742.0                          5  ...
# 4                             1416.0                          5  ...
# ...                              ...                        ...  ...
# 63159                         9111.0                          5  ...
# 63160                         9111.0                          5  ...
# 63161                         9111.0                          5  ...
# 63162                         9111.0                          5  ...
# 63163                         9111.0                          5  ...
#
#        id_parte_cuerpo_igatepmafurat  id_agente_at_igatepmafurat  \
# 0                                446                         336
# 1                                  3                           5
# 2                                  4                           5
# 3                                112                           4
# 4                                  4                           5
# ...                              ...                         ...
# 63159                            446                         336
# 63160                            446                         336
# 63161                            446                           5
# 63162                            446                         336
# 63163                              5                           5
#
#        id_mecanismo_at_igatepmafurat  otro_mecanismo_accidente_igatepmafurat  \
# 0                                  9                     herida por cuchillo
# 1                                  3
# 2                                  1
# 3                                  9                                esquirla
# 4                                  1
# ...                              ...                                     ...
# 63159                              3
# 63160                              9                                  herida
# 63161                              4
# 63162                              3
# 63163                              2
#
#                             descripcion_at_igatepmafurat  \
# 0      el trabajador se encontraba realizando su labo...
# 1      el trabajador se encontraba lavando el chasis ...
# 2      el trabajador se encontraba sentandose en una ...
# 3      el trabajador se encontraba en la labor habitu...
# 4      el trabajador se encontraba en sus labores hab...
# ...                                                  ...
# 63159  el trabajador se encontraba manipulando cilind...
# 63160  el  trabajador se encontraba  puliendo  un  ce...
# 63161  el trabajador se encontraba en la labor habitu...
# 63162  el trabajador se encontraba martillando unos t...
# 63163  el trabajador(a) se encontraba haciendo el car...
#
#       fecha_modificacion_aud_igatepmafurat  \
# 0                2009-04-02 00:00:00+00:00
# 1                2009-04-02 00:00:00+00:00
# 2                2009-04-02 00:00:00+00:00
# 3                2009-04-02 00:00:00+00:00
# 4                2009-04-02 00:00:00+00:00
# ...                                    ...
# 63159            2009-11-09 17:49:38+00:00
# 63160            2009-11-09 17:44:14+00:00
# 63161            2009-04-15 00:00:00+00:00
# 63162            2009-04-15 00:00:00+00:00
# 63163            2009-04-15 00:00:00+00:00
#
#        origen_igdactmlmacalificacionorigen  \
# 0                                        1
# 1                                        2
# 2                                        2
# 3                                        2
# 4                                        2
# ...                                    ...
# 63159                                    2
# 63160                                    2
# 63161                                    2
# 63162                                    2
# 63163                                    2
#
#       fecha_dictamen_igdactmlmacalificacionorigen  \
# 0                       2014-11-12 14:01:40+00:00
# 1                       2014-11-11 16:46:02+00:00
# 2                       2014-11-12 11:21:34+00:00
# 3                       2014-11-12 11:47:49+00:00
# 4                       2014-11-12 10:47:28+00:00
# ...                                           ...
# 63159                   2009-03-04 00:00:00+00:00
# 63160                   2010-02-15 00:00:00+00:00
# 63161                   2014-11-21 08:46:56+00:00
# 63162                   2014-10-31 00:00:00+00:00
# 63163                   2010-10-22 00:00:00+00:00
#
#        fecha_estructuracion_igdactmlmacalificacionorigen  \
# 0                              2014-10-22 00:00:00+00:00
# 1                              2014-11-07 00:00:00+00:00
# 2                              2014-11-10 00:00:00+00:00
# 3                              2014-11-10 00:00:00+00:00
# 4                              2014-11-11 00:00:00+00:00
# ...                                                  ...
# 63159                          2009-03-04 00:00:00+00:00
# 63160                          2010-02-15 00:00:00+00:00
# 63161                          2014-10-18 00:00:00+00:00
# 63162                          2014-10-18 00:00:00+00:00
# 63163                          2010-10-22 00:00:00+00:00
#
#        fecha_modificacion_aud_igdactmlmacalificacionorigen
# 0                              2016-05-13 07:20:25+00:00
# 1                              2014-11-11 16:46:02+00:00
# 2                              2014-11-12 11:21:34+00:00
# 3                              2014-11-12 11:47:49+00:00
# 4                              2014-11-12 10:47:28+00:00
# ...                                                  ...
# 63159                          2010-02-15 00:00:00+00:00
# 63160                          2010-02-15 00:00:00+00:00
# 63161                          2014-11-21 08:46:56+00:00
# 63162                          2014-11-13 12:14:28+00:00
# 63163                          2010-12-27 00:00:00+00:00
#
# [57327 rows x 28 columns]
